# %%
# report required packages
import pandas as pd
import numpy as np

# %%
# import dataset and exploratory data analysis
train_data = pd.read_csv('train.csv', index_col=0, nrows=50000)
val_data = pd.read_csv('test1.csv', index_col=0, nrows=10000)

# %%
train_data.head()
# Out:
#    android_id  apptype  carrier  dev_height  dev_ppi  dev_width  label    lan  \
# 0      316361     1199  46000.0         0.0      0.0        0.0      1    NaN
# 1      135939      893      0.0         0.0      0.0        0.0      1    NaN
# 2      399254      821      0.0       760.0      0.0      360.0      1    NaN
# 3       68983     1004  46000.0      2214.0      0.0     1080.0      0    NaN
# 4      288999     1076  46000.0      2280.0      0.0     1080.0      1  zh-CN
#
#    media_id  ntt       os    osv  package      sid     timestamp version  \
# 0       104  6.0  android      9       18  1438873  1.559893e+12       8
# 1        19  6.0  android    8.1        0  1185582  1.559994e+12       4
# 2       559  0.0  android  8.1.0        0  1555716  1.559837e+12       0
# 3       129  2.0  android  8.1.0        0  1093419  1.560042e+12       0
# 4        64  2.0  android  8.0.0        0  1400089  1.559867e+12       5
#
#      fea_hash  location   fea1_hash  cus_type
# ...

# %%
train_data.describe()
# Out:
#           android_id       apptype       carrier    dev_height       dev_ppi  \
# count   50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean   263664.643380    986.915180  39990.793980   1265.563300     71.966580
# std    234004.898192    128.855027  15502.678561    853.349859    167.636445
# min         0.000000     95.000000     -1.000000      0.000000      0.000000
# 25%         0.000000    917.000000  46000.000000    720.000000      0.000000
# 50%    233369.500000   1001.000000  46000.000000   1280.000000      0.000000
# 75%    467871.750000   1076.000000  46000.000000   2038.000000      0.000000
# max    709859.000000   1238.000000  46003.000000   3180.000000    640.000000
#
#          dev_width         label      media_id           ntt       package  \
# count  50000.00000  50000.000000  50000.000000  50000.000000  50000.000000
# mean     706.33948      0.483480    125.819600      3.081260     38.890000
# ...

# %%
val_data.head()
# Out:
#    android_id  apptype  carrier  dev_height  dev_ppi  dev_width    lan  \
# 0      317625     1181  46000.0      2196.0      2.0     1080.0     CN
# 1      435108      944  46003.0      2280.0      3.0     1080.0  zh-CN
# 2           0     1106  46000.0         0.0      0.0        0.0    NaN
# 3      451504      761  46000.0      1344.0      0.0      720.0    NaN
# 4           0     1001  46000.0       665.0      0.0      320.0  zh-CN
#
#    media_id  ntt       os    osv  package      sid     timestamp version  \
# 0       639  2.0  Android  8.1.0      188  1440682  1.559872e+12       7
# 1       704  6.0  Android  8.1.0      221  1606824  1.559739e+12       3
# 2        39  2.0  android    5.1     1562  1774642  1.559614e+12       0
# 3        54  2.0  android  7.1.1        9  1742535  1.559668e+12       0
# 4        29  5.0  Android  8.1.0        4  1689686  1.559694e+12       0
#
#      fea_hash  location   fea1_hash  cus_type
# 0  1672223856        57  3872258917       658
# ...
